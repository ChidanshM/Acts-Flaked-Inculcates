# %%
# !git pull

# %%
# !git status

# %%
# !git add git.ipynb

# %%
# !git commit -m "Updated via collab" -m " "

# %%
# !git push

# %%
# !git diff --staged

# %%
# !git stash

# %%
# !git stash list

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/0zProject/Acts-Flaked-Inculcates/

# %%
# %pwd

# %%
# !git config --local user.email "chidansh.el@gmail.com"

# %%
# !git config --local user.name "ChidanshM"
